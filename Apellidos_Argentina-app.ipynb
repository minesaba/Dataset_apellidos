# %% [markdown]
# # Apellidos más frecuentes en las provincias argentinas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/work/apellidos_mas_frecuentes_provincia.csv')
df
# Out:
#     provincia_nombre   apellido  ranking  porcentaje_poblacion_portadora  \
# 0       Buenos Aires   GONZÁLEZ        1                           1.720
# 1       Buenos Aires  RODRÍGUEZ        2                           1.326
# 2       Buenos Aires      GÓMEZ        3                           1.219
# 3       Buenos Aires  FERNÁNDEZ        4                           1.147
# 4       Buenos Aires      LÓPEZ        5                           1.092
# ..               ...        ...      ...                             ...
# 475          Tucumán    CARRIZO       16                           0.686
# 476          Tucumán     GARCÍA       17                           0.635
# 477          Tucumán     SUÁREZ       18                           0.595
# 478          Tucumán    LAZARTE       19                           0.568
# 479          Tucumán     MOLINA       20                           0.562
#
#      provincia_id
# 0               6
# 1               6
# 2               6
# ...

# %%
print(df.columns)
df = df.drop(['provincia_id'], axis=1)
# Out:
# Index(['provincia_nombre', 'apellido', 'ranking',
#        'porcentaje_poblacion_portadora', 'provincia_id'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['provincia_nombre', 'apellido', 'ranking',
#        'porcentaje_poblacion_portadora'],
#       dtype='object')

# %%
buenosaires = df[df['provincia_nombre'] == 'Buenos Aires']
catamarca = df[df['provincia_nombre'] == 'Catamarca']
chaco = df[df['provincia_nombre'] == 'Chaco']
chubut = df[df['provincia_nombre'] == 'Chubut']
CABA = df[df['provincia_nombre'] == 'Ciudad Autónoma de Buenos Aires']
cordoba = df[df['provincia_nombre'] == 'Córdoba']
corrientes = df[df['provincia_nombre'] == 'Corrientes']
entrerios = df[df['provincia_nombre'] == 'Entre Ríos']
formosa = df[df['provincia_nombre'] == 'Formosa']
jujuy = df[df['provincia_nombre'] == 'Córdoba']
lapampa = df[df['provincia_nombre'] == 'La Pampa']
larioja = df[df['provincia_nombre'] == 'La Rioja']
mendoza = df[df['provincia_nombre'] == 'Mendoza']
misiones = df[df['provincia_nombre'] == 'Misiones']
neuquen = df[df['provincia_nombre'] == 'Neuquén']
rionegro = df[df['provincia_nombre'] == 'Río Negro']
salta = df[df['provincia_nombre'] == 'Salta']
sanjuan = df[df['provincia_nombre'] == 'San Juan']
sanluis = df[df['provincia_nombre'] == 'San Luis']
santacruz = df[df['provincia_nombre'] == 'Santa Cruz']
santafe = df[df['provincia_nombre'] == 'Santa Fe']
santiagoestero = df[df['provincia_nombre'] == 'Santiago del Estero']
tierrafuego = df[df['provincia_nombre'] == 'Tierra del Fuego']
tucuman = df[df['provincia_nombre'] == 'Tucumán']

print('BUENOS AIRES:', buenosaires['apellido'].head(1))
print('CATAMARCA:', catamarca['apellido'].head(1))
print('CHACO:', chaco['apellido'].head(1))
print('CHUBUT:', chubut['apellido'].head(1))
print('CABA:', CABA['apellido'].head(1))
print('CORDOBA:', cordoba['apellido'].head(1))
print('CORRIENTES:', corrientes['apellido'].head(1))
print('ENTRE RIOS:', entrerios['apellido'].head(1))
print('FORMOSA:', formosa['apellido'].head(1))
print('JUJUY:', jujuy['apellido'].head(1))
print('LA PAMPA:', lapampa['apellido'].head(1))
print('LA RIOJA:', larioja['apellido'].head(1))
print('MENDOZA:', mendoza['apellido'].head(1))
print('MISIONES:', misiones['apellido'].head(1))
print('NEUQUEN:', neuquen['apellido'].head(1))
print('RIO NEGRO:', rionegro['apellido'].head(1))
print('SALTA:', salta['apellido'].head(1))
print('SAN JUAN:', sanjuan['apellido'].head(1))
print('SAN LUIS:', sanluis['apellido'].head(1))
print('SANTA CRUZ:', santacruz['apellido'].head(1))
print('SANTA FE:', santafe['apellido'].head(1))
print('SANTIAGO DEL ESTERO:', santiagoestero['apellido'].head(1))
print('TIERRA DEL FUEGO:', tierrafuego['apellido'].head(1))
print('TUCUMAN:', tucuman['apellido'].head(1))
# Out:
# BUENOS AIRES: 0    GONZÁLEZ
# Name: apellido, dtype: object
# CATAMARCA: 20    CARRIZO
# Name: apellido, dtype: object
# CHACO: 40    GÓMEZ
# Name: apellido, dtype: object
# CHUBUT: 60    GONZÁLEZ
# Name: apellido, dtype: object
# CABA: 80    GONZÁLEZ
# Name: apellido, dtype: object
# CORDOBA: 100    GONZÁLEZ
# Name: apellido, dtype: object
# CORRIENTES: 120    GÓMEZ
# Name: apellido, dtype: object
# ENTRE RIOS: 140    GONZÁLEZ
# Name: apellido, dtype: object
# FORMOSA: 160    GONZÁLEZ
# Name: apellido, dtype: object
# JUJUY: 100    GONZÁLEZ
# Name: apellido, dtype: object
# LA PAMPA: 200    RODRÍGUEZ
# Name: apellido, dtype: object
# LA RIOJA: 220    DÍAZ
# Name: apellido, dtype: object
# MENDOZA: 240    GONZÁLEZ
# Name: apellido, dtype: object
# MISIONES: 260    RODRÍGUEZ
# Name: apellido, dtype: object
# NEUQUEN: 280    GONZÁLEZ
# Name: apellido, dtype: object
# RIO NEGRO: 300    GONZÁLEZ
# Name: apellido, dtype: object
# SALTA: 320    LÓPEZ
# Name: apellido, dtype: object
# ...

# %% [markdown]
# ### Conclusión:

# %% [markdown]
# El apellido más frecuente es GONZÁLEZ. Éste lidera en ranking en muchas de las provincias (tales como: Buenos Aires, Chubut, Córdoba, Entre Ríos, Formosa, Jujuy, Mendoza, Neuquén, Río Negro, Santa Cruz, Santa Fe, Tierra del Fuego) y en la Ciudad Autónoma de Buenos Aires.

# %% [markdown]
# Visualizar el informe en Looker Studio, a través del siguiente link: https://lookerstudio.google.com/embed/reporting/f8b1223d-a753-4caf-9964-b38d82de007d/page/p_ssvirjvf3c

# %% [markdown]
# Fuente de los datos: https://www.datos.gob.ar/dataset/renaper-distribucion-apellidos-argentina/archivo/renaper_2.2 [Fecha de consulta: 15/2/2023]

# %% [markdown]
#                       María Inés Abarrategui Fernández https://www.linkedin.com/in/mariainesabarrateguif/

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7ea004b1-d450-4e40-8e2a-b2454d1071e4' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
